# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/rkais/Downloads/ec_score_file.csv")

# %%
df.head()
# Out:
#           NPI   Org_PAC_ID  Provider Last Name  Provider First Name  \
# 0  1003028101          NaN                KATZ              KENNETH
# 1  1003028556          NaN             HEIDARI                 NEDA
# 2  1003220351          NaN             NAUMOVA                YULIA
# 3  1003808494          NaN               CHANG               ANDREW
# 4  1003813262          NaN              HALAWA                ABDUL
#
#        source   Facility-based scoring Certification number   Facility Name  \
# 0  individual                                           NaN             NaN
# 1  individual                                           NaN             NaN
# 2  individual                                           NaN             NaN
# 3  individual                                           NaN             NaN
# 4  individual                                           NaN             NaN
#
#     Quality_category_score   PI_category_score   IA_category_score  \
# ...

# %%
df.head(3)
# Out:
#           NPI   Org_PAC_ID  Provider Last Name  Provider First Name  \
# 0  1003028101          NaN                KATZ              KENNETH
# 1  1003028556          NaN             HEIDARI                 NEDA
# 2  1003220351          NaN             NAUMOVA                YULIA
#
#        source   Facility-based scoring Certification number   Facility Name  \
# 0  individual                                           NaN             NaN
# 1  individual                                           NaN             NaN
# 2  individual                                           NaN             NaN
#
#     Quality_category_score   PI_category_score   IA_category_score  \
# 0                      NaN                 NaN                 NaN
# 1                   94.641                58.0                20.0
# 2                      NaN                 NaN                 NaN
#
#     Cost_category_score   final_MIPS_score_without_CPB   final_MIPS_score
# ...

# %%
df.describe()
# Out:
#                 NPI    Org_PAC_ID  \
# count  6.988830e+05  6.971340e+05
# mean   1.499688e+09  4.920399e+09
# std    2.879072e+08  2.850452e+09
# min    1.003000e+09  4.210078e+07
# 25%    1.245861e+09  2.567366e+09
# 50%    1.497956e+09  4.789830e+09
# 75%    1.740847e+09  7.315850e+09
# max    1.993000e+09  9.931538e+09
#
#         Facility-based scoring Certification number   Facility Name  \
# count                                           0.0             0.0
# mean                                            NaN             NaN
# std                                             NaN             NaN
# min                                             NaN             NaN
# 25%                                             NaN             NaN
# 50%                                             NaN             NaN
# 75%                                             NaN             NaN
# max                                             NaN             NaN
#
# ...

# %%
df.shape
# Out:
# (698883, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698883 entries, 0 to 698882
# Data columns (total 13 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   NPI                                           698883 non-null  int64
#  1    Org_PAC_ID                                   697134 non-null  float64
#  2    Provider Last Name                           698858 non-null  object
#  3    Provider First Name                          698870 non-null  object
#  4    source                                       698883 non-null  object
#  5    Facility-based scoring Certification number  0 non-null       float64
#  6    Facility Name                                0 non-null       float64
#  7    Quality_category_score                       604815 non-null  float64
#  8    PI_category_score                            444186 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['NPI', ' Org_PAC_ID', ' Provider Last Name', ' Provider First Name',
#        ' source', ' Facility-based scoring Certification number',
#        ' Facility Name', ' Quality_category_score', ' PI_category_score',
#        ' IA_category_score', ' Cost_category_score',
#        ' final_MIPS_score_without_CPB', ' final_MIPS_score'],
#       dtype='object')

# %%
df[df[ ' final_MIPS_score_without_CPB']>60]
# Out:
#                NPI    Org_PAC_ID  Provider Last Name  Provider First Name  \
# 1       1003028556           NaN             HEIDARI                 NEDA
# 5       1003813783           NaN              TRIOLO               DONALD
# 11      1003864059           NaN              HUSTED                ROGER
# 17      1003964420           NaN             TRIVEDI                MANOJ
# 18      1003989237           NaN             MENASHE              RICHARD
# ...            ...           ...                 ...                  ...
# 698849  1720032477  9.931529e+09              WORREL               DANIEL
# 698854  1760617526  9.931529e+09               KHAIR              MAHMOUD
# 698857  1790816122  9.931529e+09             SCOVELL                 JOHN
# 698867  1922028638  9.931529e+09               BRUCK              WILLIAM
# 698882  1982609657  9.931538e+09               MINOR                 MARK
#
#             source   Facility-based scoring Certification number  \
# ...

# %%
df.query('` Provider First Name` == "ROGER"')
# Out:
#                NPI    Org_PAC_ID  Provider Last Name  Provider First Name  \
# 11      1003864059           NaN              HUSTED                ROGER
# 121     1073536405           NaN            MAXFIELD                ROGER
# 206     1124162961           NaN              ORSINI                ROGER
# 214     1134110547           NaN               BOYCE                ROGER
# 677     1396742524           NaN              PITZEN                ROGER
# ...            ...           ...                 ...                  ...
# 690083  1861493413  9.830095e+09              MENDIS                ROGER
# 690623  1528012630  9.830111e+09                PARO                ROGER
# 691455  1548240310  9.830174e+09            SIDDOWAY                ROGER
# 695147  1467441691  9.931013e+09                FREY                ROGER
# 697256  1730182619  9.931239e+09            ACHEATEL                ROGER
#
#             source   Facility-based scoring Certification number  \
# ...
