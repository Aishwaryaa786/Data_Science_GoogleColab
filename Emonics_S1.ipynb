# %%
import pandas as pd
df1 = {"Aishu": [1,2,3,4,5],"Sreeja":[111,112,113,1141,115]}
df1=pd.DataFrame(df1)
df1
# Out:
#    Aishu  Sreeja
# 0      1     111
# 1      2     112
# 2      3     113
# 3      4    1141
# 4      5     115

# %%
fg=pd.Series([12,34,56,78,90])
df1["Navya"]=fg
df1
# Out:
#    Aishu  Sreeja  Navya
# 0      1     111     12
# 1      2     112     34
# 2      3     113     56
# 3      4    1141     78
# 4      5     115     90

# %%
x=['Aishu','navya','Sreeja','Navya','Divya']
hj =pd.Series(x)
df1['Names']=hj
df1
df1=pd.concat([df1,pd.DataFrame({'Aishu':[1],'Sreeja':[1], 'Navya':[1],'Names':[1]})], ignore_index = True)
df1
# Out:
#    Aishu  Sreeja  Navya   Names
# 0      1     111     12   Aishu
# 1      2     112     34   navya
# 2      3     113     56  Sreeja
# 3      4    1141     78   Navya
# 4      5     115     90   Divya
# 5      1       1      1       1

# %%
df1.loc[1:3,['Aishu','Sreeja']]
df1.iloc[1:4,1:2]
# Out:
#    Sreeja
# 1     112
# 2     113
# 3    1141
